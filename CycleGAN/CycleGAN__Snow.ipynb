# %% [markdown]
# # CycleGAN : Snow --> No snow

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# %cd pytorch-CycleGAN-and-pix2pix
# !pip install -r requirements.txt
# !pip install torchvision tqdm
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2516, done.
# remote: Total 2516 (delta 0), reused 0 (delta 0), pack-reused 2516 (from 1)
# Receiving objects: 100% (2516/2516), 8.20 MiB | 26.66 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.
# /content/pytorch-CycleGAN-and-pix2pix
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p datasets/nordic_snow
# !cp -r /content/drive/MyDrive/nordic_snow_cyclegan/* datasets/nordic_snow/

# %%
# !mkdir -p datasets/nordic_test_only_snowy
# !cp -r /content/drive/MyDrive/dataset/nvd/nvd_dataset_small/images/test/* datasets/nordic_test_only_snowy

# %%
# Train CycleGAN
import os
os.chdir('/content/pytorch-CycleGAN-and-pix2pix')

# !python train.py \
  --dataroot ./datasets/nordic_snow \
  --name nordic_clear2snow \
  --model cycle_gan \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 30 \
  --batch_size 1 \
  --load_size 764 \
  --crop_size 764 \
  --preprocess resize_and_crop \
  --netG resnet_9blocks \
  --display_id 0 \
  --no_dropout \
  --lambda_identity 0.5
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 764                           	[default: 256]
#                  dataroot: ./datasets/nordic_snow        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %%
# Test CycleGAN with snowy images
# !python test.py \
  --dataroot ./datasets/nordic_test_only_snowy \
  --name nordic_clear2snow \
  --model test \
  --phase test \
  --no_dropout \
  --direction BtoA \
  --epoch latest \
  --model_suffix _B \
  --load_size 1024 \
  --crop_size 1024 \
  --netG resnet_9blocks \
  --preprocess none \
  --results_dir /content/drive/MyDrive/nordic_snow_results_desnowed_30epoch/
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 1024                          	[default: 256]
#                  dataroot: ./datasets/nordic_test_only_snowy	[default: None]
#              dataset_mode: single
#                 direction: BtoA                          	[default: AtoB]
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 1024                          	[default: 256]
#          max_dataset_size: inf
#                     model: test
# ...
